# %%
# variable

# %%
# variable is a name used to stored data

# %%
student_name = "Aditi"

# %%
print(student_name)
# Out:
# Aditi

# %%
student_age = 18

# %%
print(student_age)
# Out:
# 18

# %%
student_marks = 89.20

# %%
print(student_marks)
# Out:
# 89.2

# %%
# printing with labels

# %%
name = "Aditi"

# %%
print("name:" ,name)
# Out:
# name: Aditi

# %%
age = 18

# %%
print("age:" ,age)
# Out:
# age: 18

# %%
city = "Pune"

# %%
print("city:" ,city)
# Out:
# city: Pune

# %%
# changing the variable values

# %%
Course= "python"

# %%
print("Before changing:" ,Course)
# Out:
# Before changing: python

# %%
Course = "Data Science"

# %%
print("After Changing:" ,Course)
# Out:
# After Changing: Data Science

# %%
#Multiple variables

# %%
x,y,z=100,200,300

# %%
print("X", x)
# Out:
# X 100

# %%
print("Y", y)
# Out:
# Y 200

# %%
print("Z", z)
# Out:
# Z 300

# %%
#Same value to multiple variables

# %%
maths = science = English = 90

# %%
print("Maths", maths)
# Out:
# Maths 90

# %%
print("Science", science)
# Out:
# Science 90

# %%
print("English", English)
# Out:
# English 90

# %%
# Invalid variables name

# %%
2name="Aditi"
# Out:
#   File "/tmp/ipykernel_639/3314660295.py", line 1
#     2name="Aditi"
#     ^
# SyntaxError: invalid decimal literal

# %%
student-name="Aditi"
# Out:
#   File "/tmp/ipykernel_639/1470650311.py", line 1
#     student-name="Aditi"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
full name="Jadhav"
# Out:
#   File "/tmp/ipykernel_639/794019609.py", line 1
#     full name="Jadhav"
#          ^
# SyntaxError: invalid syntax

# %%
# dynamic typing

# %%
# python automatically understand the data types

# %%
value=100

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
value="Python"

# %%
print(type(value))
# Out:
# <class 'str'>

# %%
value=34.87

# %%
print(type(value))
# Out:
# <class 'float'>

# %%
# Input Example

# %%
name = input("Enter your name:")
# Out:
# Enter your name:aditi

# %%
print("Name:", name)
# Out:
# Name: aditi

# %%
age = input("Enter your age: ")
# Out:
# Enter your age: 18

# %%
print("Age:", age)
# Out:
# Age: 18

# %%
age = int(input("Enter age:"))
# Out:
# Enter age:18

# %%
print(age)
# Out:
# 18

# %%
type(age)
# Out:
# int

# %%
# common Escape Characters

# %%
# Escape characters are special symbols(starting with \) used to add formatting or special meaning inside a string

# %%
 #New Line -> \n
# Moves text to the next line

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
#Tab Space -> \t
#Adds horizontal space (tab)

# %%
print("Hello\tWorld")
# Out:
# Hello	World

# %%
# Backslash -> \\

# %%
print("C:\\Users\\Rahul")
# Out:
# C:\Users\Rahul

# %%
#Single Quote -> \
#Used when string is inside single quotes

# %%
print('It\'s Python')
# Out:
# It's Python

# %%
# Double Quote -> \"
# Used when string is inside double quotes

# %%
print("He said \"Hello\" ")
# Out:
# He said "Hello"

# %%
# Backspace -> \b
# Removes one character before it

# %%
print("Helloo\b")
# Out:
# Helloo

# %%
# Unicode Character

# %%
# A Unicode character is a universal encoding system that assigns a unique number (code point)
# to every character in every language.

# %%
print("\u0041")
# Out:
# A

# %%
print("\u0939")
# Out:
# ह

# %%
# print() function
# It is used to display output on the

# %%
#Printing text

# %%
print("Hello World")
# Out:
# Hello World

# %%
# Printing variables

# %%
name = "Aditi"
print(name)
# Out:
# Aditi

# %%
# Printing multiple values

# %%
name = "Aditi"
age = 19

# %%
print(name, age)
# Out:
# Aditi 19

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

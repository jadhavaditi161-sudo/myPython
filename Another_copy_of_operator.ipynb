# %%
#Arithematic operator

# %%
a = 10
b = 3

# %%
#Addition

# %%
a + b
# Out:
# 13

# %%
30
# Out:
# 30

# %%
a/b
# Out:
# 3.3333333333333335

# %%
a%b
# Out:
# 1

# %%
a//b
# Out:
# 3

# %%
# comparison operator

# %%
x = 5

# %%
y = 10

# %%
#Equal to

# %%
x == y
# Out:
# False

# %%
#Not equal to

# %%
x != y
# Out:
# True

# %%
#Greater than

# %%
x > y
# Out:
# False

# %%
# less than

# %%
x < y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1398/2052631419.py in <cell line: 0>()
# ----> 1 x < y
#
# NameError: name 'x' is not defined

# %%
a =56
b= 34

# %%
a < b
# Out:
# False

# %%
a >b
# Out:
# True

# %%
# Greater than or equal to

# %%
a >= b
# Out:
# True

# %%
# less than or equal to

# %%
a <= b
# Out:
# False

# %%
# logical operator

# %%
# add: returns true only if both conditions are true
# or: returns true if at least one condition is true
# not: reverse the result, inverting true or false and vice versa

# %%
a = True
b = False

# %%
# AND

# %%
a and b
# Out:
# False

# %%
#OR

# %%
a or b
# Out:
# True

# %%
# NOT

# %%
not a
# Out:
# False

# %%
# Assignment operators

# %%
x = 5

# %%
x + 5
# Out:
# 10

# %%
x -5
# Out:
# 0

# %%
x = x+5

# %%
print(x)
# Out:
# 10

# %%
print("x=",x-5)
# Out:
# x= 5

# %%
#x=x=+3

# %%
x += 3

# %%
x
# Out:
# 13

# %%
#x=x - 2

# %%
x -= 2

# %%
x
# Out:
# 11

# %%
#x = X*4

# %%
x *= 4

# %%
x
# Out:
# 44

# %%
#x =/5

# %%
x /= 5

# %%
x
# Out:
# 8.8

# %%
# membership operator

# %%
fruits =["apple","Banana","mango"]

# %%
"apple" in fruits
# Out:
# True

# %%
"grapes" not in fruits
# Out:
# True

# %%
# identify operator

# %%
a = [1,2,3]
b = a
c = [1,2,3]

# %%
#True

# %%
a is b
# Out:
# True

# %%
#False

# %%
a is c
# Out:
# False

# %%
#True

# %%
a is not c
# Out:
# True

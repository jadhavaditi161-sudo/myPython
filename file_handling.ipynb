# %%
# File hanwdling in python is the process of creating, reading,writing , updating, and deleting files using function Like open()
# and file modes.

# %%
# Create a Sample File

# %%
with open("sample.txt", "w") as f:
  f.write("Name: Aditi\n")
  f.write("Role:  Data Scientist\n")
  f.write("Location : India\n")

# %%
# Reading the file

# %%
with open("sample.txt", "r") as f:
  data = f.read()
  print(data)
# Out:
# Name: Aditi
# Role:  Data Scientist
# Location : India

# %%
# Reading Line by line

# %%
with open("sample.txt", "r") as f:
  for line in f:
    print(line.strip())
# Out:
# Name: Aditi
# Role:  Data Scientist
# Location : India

# %%
with open("python.txt", "w") as f:
  f.write("Information About Python\n")
  f.write("========================\n")
  f.write("Python is a high-level, interpreted programming language.\n")
  f .write("\t- Easy to learn and use\n")
  f .write("\t- Supports object-oriented programming\n")
  f.write("\t- Has a large standard library\n")
  f.write("\t- Widely used in AI, data science, and web development\n")
  f .write("\nDeveloper: Guido van Rossum\n")
  f .write("First Released: 1991\n")
  f.write("Python is a high-level, interpreted programming language that is known for its simple and readable syntax. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including object-oriented, procedural, and functional programming. Its ease of use makes it a popular choice for beginners and experienced developers alike.\n\n")

  f.write("Python is widely used in various fields such as web development, data science, artificial intelligence, machine learning, automation, and software development. It provides a large standard library and a vast ecosystem of third-party packages.\\n\\tThis flexibility and versatility have made Python one of the most popular programming languages in the world.")
  f.write("Many developers describe Python as \\\"powerful\\\" and \\\"versatile\\\" due to its large collection of libraries.")
  f.write("In Python, the backslash character (\\) is an escape character used to represent special characters in strings. For example, \\n creates a new line, \\t creates a tab space, and \\\\ displays a single backslash. These escape sequences make text formatting easier in programs.")

# %%
with open("python.txt", "r") as f:
  data = f.read()
  print(data)
# Out:
# Information About Python
# ...
# Python is a high-level, interpreted programming language.
# 	- Easy to learn and use
# 	- Supports object-oriented programming
# 	- Has a large standard library
# 	- Widely used in AI, data science, and web development
#
# Developer: Guido van Rossum
# First Released: 1991
# Python is a high-level, interpreted programming language that is known for its simple and readable syntax. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including object-oriented, procedural, and functional programming. Its ease of use makes it a popular choice for beginners and experienced developers alike.
#
# ...

# %%
with open("python.txt", "r") as f:
  for line in f:
    print(line.strip())
# Out:
# Information About Python
# ...
# Python is a high-level, interpreted programming language.
# - Easy to learn and use
# - Supports object-oriented programming
# - Has a large standard library
# - Widely used in AI, data science, and web development
#
# Developer: Guido van Rossum
# First Released: 1991
# Python is a high-level, interpreted programming language that is known for its simple and readable syntax. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including object-oriented, procedural, and functional programming. Its ease of use makes it a popular choice for beginners and experienced developers alike.
#
# ...

# %%
# Appending Data

# %%
with open("sample.txt", "a") as f:
  f.write("Appended line 1\n")
  f.write("Appended line 2\n")

# %%
with open("sample.txt", "r") as f:
  data=f.read()
  print(data)
# Out:
# Name: Aditi
# Role:  Data Scientist
# Location : India
# Appended line 1
# Appended line 2

# %%
with open("sample.txt", "r") as f:
  for line in f:
    print(line.strip())
# Out:
# Name: Aditi
# Role:  Data Scientist
# Location : India
# Appended line 1
# Appended line 2

# %%
# check if file Exist

# %%
import os

if os.path.exists("sample.txt"):
  print("File exist")
else:
  print("File not found")
# Out:
# File exist

# %%
# Delete the file

# %%
#import os
#os.remove("sample.txt")

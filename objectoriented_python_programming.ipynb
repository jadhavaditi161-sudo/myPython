# %%
# Class

# %%
# class is a blueprint used to create objects.

# %%
class Student:
  pass

# %%
 class Car:
  pass

# %%
class Teacher:
  pass

# %%
# object

# %%
# object is an instances of a class

# %%
class StudentObject:
  pass

# %%
s1 = StudentObject()

# %%
c1 = Car()

# %%
t1 = Teacher()

# %%
class Employee:
  pass

# %%
e1 = Employee()

# %%
class Colour:
  pass

# %%
c2 = Colour()

# %%
class Triangle:
  pass

# %%
t2 = Triangle()

# %%
print(type(s1))
# Out:
# <class '__main__.StudentObject'>

# %%
print(type(t2))
# Out:
# <class '__main__.Triangle'>

# %%
class Student:
  def show(self):
    print("Method Called")

# %%
s1 = Student()

# %%
s1.show()
# Out:
# Method Called

# %%
class Student1:
  def display(self):
    print("I am Aditi")

# %%
st = Student1()

# %%
st.display()
# Out:
# I am Aditi

# %%
# Magic Methods

# %%
# Magic methods are special methods with doble underscores(__) that Python automatically called

# %%
# Magic methods customize object behavior

# %%
# __init__() - Intialize Object

# %%
class Student:
  def __init__(self,name):
    self.name = name

# %%
s = Student("Aditi")

# %%
print(s.name)
# Out:
# Aditi

# %%
# Constructor

# %%
# Constructor initializes object data when an object is created

# %%
# __new__() creates the object  (allocates memory and returns the instances)

# %%
# __init__() initialize the object after it has been created

# %%
class StudentConstructor:
  def __init__(self):
    print("Constructor Called")

# %%
obj = StudentConstructor()
# Out:
# Constructor Called

# %%
 class TeacherConstructor:
  def __init__(self):
    print("I like python programing")

# %%
t3 = TeacherConstructor()
# Out:
# I like python programing

# %%
# Instance Variable

# %%
# Instance variable are variables that belong to an object (instance) and store data specific to that object

# %%
# instance variable are variables defined using self inside a class and are unique to each object of that class

# %%
class STUdent:
  def __init__(self, name):
    self.name= name # Instances Variable

# %%
s1 =Student("Aditi")

# %%
s1.name
# Out:
# 'Aditi'

# %%
class Student:
  def __init__(self, name, marks):
    self.name= name
    self.marks= marks

# %%
s = Student("Aditi",  90)

# %%
s.name
# Out:
# 'Aditi'

# %%
s.marks
# Out:
# 90

# %%
# Instance method are methods that operate on a specific object and use self as their first parameter

# %%
class Student:
  def __init__(self,name):
    self.name = name

  def show(self): # Instance method
     print(self.name)

# %%
s = Student("Aditi")

# %%
s.show()
# Out:
# Aditi

# %%
# Class Variable

# %%
 # Class variables  are stored by all objects

# %%
class Student:
  school = "ABC School" #Class Variable

  def __init__(self,name):
    self.name= name

# %%
s1 = Student("Aditi")
s2 = Student("Aaradhy")

# %%
s1.school
# Out:
# 'ABC School'

# %%
s2.school
# Out:
# 'ABC School'

# %%
class Car:
  musicsystem = "JBL"

  def __init__(self,car_name):
    self. car_name= car_name

# %%
c11 = Car("Honda")
c22 = Car("Thar")

# %%
c11.musicsystem
# Out:
# 'JBL'

# %%
c22.musicsystem
# Out:
# 'JBL'

# %%
# class Method
# A class method works with the class itself, not a specific object

# %%
# @classmethod tells python this is a class method

# %%
class Student:
  @classmethod
  def show_class(cls):
    print("Class Method")

# %%
Student.show_class()
# Out:
# Class Method

# %%
# static Method

# %%
# static methods are utility methods that do not use self or cls

# %%
# Works with neither the object nor the clas

# %%
class Calculator:

  @staticmethod
  def add(a,b):
    return a + b

# %%
Calculator.add(10,20)
# Out:
# 30

# %%
class Calculator:
  @staticmethod
  def mul(a,b):
    return a*b

# %%
Calculator.mul(23,2)
# Out:
# 46

# %%
# Encapsulation is the process of hiding data using private variables and providing controlled access through metho

# %%
# Encapsulation protects data by restricting direct access

# %%
# Encapsulation protects data by restricting direct access

# %%
# Use double underscores (__) to make an attribute private

# %%
class BankAccount:

    def __init__(self, balance):
        self.__balance = balance

    def get_balance(self):
        return self.__balance

# %%
BankAccount(1000).get_balance()
# Out:
# 1000

# %%
# Single Inheritance

# %%
# Single inheritance allows one child class to inherit from one parent

# %%
class Animal:
    def eat(self):
        print("Eating")

class Dog(Animal):
    pass

# %%
Dog().eat()
# Out:
# Eating

# %%
# Method overriding

# %%
# Method overriding replaces a parent method in the child class

# %%
class Vehicle:
    def start(self):
        print("Vehicle is starting...")


class Car(Vehicle):
    def start(self):
        print("Car is starting...")

# %%
car = Car()

# %%
car.start()
# Out:
# Car is starting...

# %%
#Polymorphism
#Same method name, different Behavior

# %%
class Dog:
  def speak(self):
    return "Bark"
class Cat:
  def speak(self):
    return "Meow"

# %%
C=Cat()

# %%
C.speak()
# Out:
# 'Meow'

# %%
D=Dog()

# %%
D.speak()
# Out:
# 'Bark'

# %%
#Abstraction means hiding unnecessary details and showing only the important features to the user

# %%
# Abstract classes

# %%
# ABC is a class used to force child classes to implement certain methods
# @abstractmethod marks methods that child classes must provide

# %%
# ABC = a rule book
# @abstractmethod = compulsory method

# %%
# An abstract class is a class that cannot be instantiated and is used as a blueprint for other classes

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):

    def area(self):
        return 78.5

# %%
Circle().area()
# Out:
# 78.5

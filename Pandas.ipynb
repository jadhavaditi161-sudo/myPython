# %%
# %pip install pandas

# %%
#pandas

# %%
# install pandas

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s = pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
dic1=["name:","Aditi","age:","18","marks:","84.71"]

# %%
dic1
# Out:
# ['name:', 'Aditi', 'age:', '18', 'marks:', '84.71']

# %%
s= pd.Series(["name:","Aditi","age:","18","marks:","84.71"])

# %%
s
# Out:
# 0     name:
# 1     Aditi
# 2      age:
# 3        18
# 4    marks:
# 5     84.71
# dtype: object

# %%
s=pd.Series(5,index=[0,1,2,3,4])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
#attributes

# %%
s = pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
s*2
# Out:
# a    20
# b    40
# c    60
# dtype: int64

# %%
s=pd.Series([10,None,20])

# %%
s
# Out:
# 0    10.0
# 1     NaN
# 2    20.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    10.0
# 2    20.0
# dtype: float64

# %%
s
# Out:
# 0    10.0
# 1     NaN
# 2    20.0
# dtype: float64

# %%
s.fillna(5)
# Out:
# 0    10.0
# 1     5.0
# 2    20.0
# dtype: float64

# %%
s=pd.Series([1,2,2,3,3,3])

# %%
s
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    3
# 5    3
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    3
# 2    2
# 1    1
# Name: count, dtype: int64

# %%
s=pd.Series([10,20,30,40], index=['a','b','c','d'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
data = {
    "Name": ["Aditi", "Rahul", "Priya"],
    "Age": [20, 22, 21],
    "City": ["Mumbai", "Pune", "Delhi"]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#     Name  Age    City
# 0  Aditi   20  Mumbai
# 1  Rahul   22    Pune
# 2  Priya   21   Delhi

# %%
data1 = {
    "Subject": ["Java", "PYthon", "C++"],
    "Marks": [67,78,98],
    "Grade": ["C", "B", "A"]
}

# %%
data1 = {
    "Subject": ["Java", "PYthon", "C++"],
    "Marks": [67,78,98],
    "Grade": ["C", "B", "A"]
}
df = pd.DataFrame(data1)

# %%
print(df)
# Out:
#   Subject  Marks Grade
# 0    Java     67     C
# 1  PYthon     78     B
# 2     C++     98     A

# %%
df.to_csv('marks_data.csv', index=False)

# %%
df = pd.read_csv("marks_data.csv")

# %%
df
# Out:
#   Subject  Marks Grade
# 0    Java     67     C
# 1  PYthon     78     B
# 2     C++     98     A

# %%
df.tail()
# Out:
#   Subject  Marks Grade
# 0    Java     67     C
# 1  PYthon     78     B
# 2     C++     98     A

# %%
df.head()
# Out:
#   Subject  Marks Grade
# 0    Java     67     C
# 1  PYthon     78     B
# 2     C++     98     A

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Subject', 'Marks', 'Grade'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Subject  3 non-null      object
#  1   Marks    3 non-null      int64
#  2   Grade    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#            Marks
# count   3.000000
# mean   81.000000
# std    15.716234
# min    67.000000
# 25%    72.500000
# 50%    78.000000
# 75%    88.000000
# max    98.000000

# %%
df.isnull().sum()
# Out:
# Subject    0
# Marks      0
# Grade      0
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#   Subject  Marks Grade
# 0    Java     67     C
# 1  PYthon     78     B
# 2     C++     98     A

# %%
df['Marks'] = df['Marks'].astype(float)

# %%
df
# Out:
#   Subject  Marks Grade  Maeks
# 0    Java   67.0     C   67.0
# 1  PYthon   78.0     B   78.0
# 2     C++   98.0     A   98.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Subject  3 non-null      object
#  1   Marks    3 non-null      float64
#  2   Grade    3 non-null      object
#  3   Maeks    3 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 228.0+ bytes

# %%
df["Subject"]
# Out:
# 0      Java
# 1    PYthon
# 2       C++
# Name: Subject, dtype: object

# %%
df[["Subject","Grade","Marks"]]
# Out:
#   Subject Grade  Marks
# 0    Java     C   67.0
# 1  PYthon     B   78.0
# 2     C++     A   98.0

# %%
df= df.sort_values(by="Marks", ascending=False)

# %%
df
# Out:
#   Subject  Marks Grade  Maeks
# 2     C++   98.0     A   98.0
# 1  PYthon   78.0     B   78.0
# 0    Java   67.0     C   67.0

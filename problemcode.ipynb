# %%
student={"name": "Aditi", "age": 18, "course": "python"}

# %%
print(student)
# Out:
# {'name': 'Aditi', 'age': 18, 'course': 'python'}

# %%
print(student.values())
# Out:
# dict_values(['Aditi', 18, 'python'])

# %%
student["Marks"]= 90

# %%
print(student)
# Out:
# {'name': 'Aditi', 'age': 18, 'course': 'python', 'Marks': 90}

# %%
student["age"]=21

# %%
print(student)
# Out:
# {'name': 'Aditi', 'age': 21, 'course': 'python', 'Marks': 90}

# %%
del student["age"]

# %%
print(student)
# Out:
# {'name': 'Aditi', 'course': 'python', 'Marks': 90}

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'course', 'Marks'])
